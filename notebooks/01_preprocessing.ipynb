# %%
# !pip show accelerate

# %%
# !pip install git+https://github.com/huggingface/accelerate

# %%
# Accelerate parts
from accelerate import Accelerator, notebook_launcher # main interface, distributed launcher
from accelerate.utils import set_seed # reproducability across devices

# %%
# %pip install nltk
# %pip install spacy
import nltk
nltk.download('punkt_tab')
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
nltk.download('stopwords')
stemmer = PorterStemmer()
Lemma = WordNetLemmatizer()
nltk.download('wordnet')
import spacy
import en_core_web_sm
import pandas as pd

# %%
from tqdm import tqdm
import spacy
from nltk import word_tokenize, sent_tokenize
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner","tok2vec"])

# %%
# %pip install torch
# %pip install rouge_score

# %%
#Pre-Preprocessing text of training data:
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

pre_corpus=[]
# # Load the English language model
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner","tok2vec"])

texts = list(pd.read_csv(r"/kaggle/input/nlp-assign/train(1).csv").text)

# Process the texts
for doc in tqdm(nlp.pipe(texts, batch_size=50)):
    # Perform lemmatization and stopword removal
    lemmatized_tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct and token.is_alpha]

    # Join the tokens back into a string
    processed_text = " ".join(lemmatized_tokens)

    # Print the processed text
    pre_corpus.append(processed_text)


import pandas as pd


# Convert list to DataFrame
df2 = pd.DataFrame(pre_corpus, columns=["text"])

# Save as CSV
df2.to_csv("pre_corpus.csv", index=False)  # Set index=False to avoid unnecessary index column

print("CSV file saved successfully!")

# %%
df2 = pd.read_csv("/kaggle/input/nlp-assign/pre_corpus.csv")  # df2 is the preprocessed Text dataset
corpus = df2["Text"].dropna().tolist()

# %%
df2

# %%
df = pd.read_csv(r"/kaggle/input/nlp-assign/train(1).csv")
df_title = df.title  ## contains title of training data

# %%
#Pre-Preprocessing titles of training data:
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

pre_corpus=[]
# # Load the English language model
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner","tok2vec"])

texts = list(df_title)

# Process the texts
for doc in tqdm(nlp.pipe(texts, batch_size=50)):
    # Perform lemmatization and stopword removal
    lemmatized_tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct and token.is_alpha]

    # Join the tokens back into a string
    processed_text = " ".join(lemmatized_tokens)

    # Print the processed text
    pre_corpus.append(processed_text)

# %%
import pandas as pd


# Convert list to DataFrame
df = pd.DataFrame(pre_corpus, columns=["title"])

# Save as CSV
df.to_csv("pre_corpus_heading.csv", index=False)  # Set index=False to avoid unnecessary index column

print("CSV file saved successfully!")

# %%
df_title = df
df_title

# %%
#Pre-Preprocessing test data titles:
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

pre_corpus=[]
# # Load the English language model
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner","tok2vec"])

texts = list(pd.read_csv(r"/kaggle/input/nlp-assign/test(1).csv").title)

# Process the texts
for doc in tqdm(nlp.pipe(texts, batch_size=50)):
    # Perform lemmatization and stopword removal
    lemmatized_tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct and token.is_alpha]

    # Join the tokens back into a string
    processed_text = " ".join(lemmatized_tokens)

    # Print the processed text
    pre_corpus.append(processed_text)

df_test_title = pd.DataFrame(pre_corpus, columns=["title"])

# %%
#Pre-Preprocessing test data titles:
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

pre_corpus=[]
# # Load the English language model
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner","tok2vec"])

texts = list(pd.read_csv(r"/kaggle/input/nlp-assign/test(1).csv").title)

# Process the texts
for doc in tqdm(nlp.pipe(texts, batch_size=50)):
    # Perform lemmatization and stopword removal
    lemmatized_tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct and token.is_alpha]

    # Join the tokens back into a string
    processed_text = " ".join(lemmatized_tokens)

    # Print the processed text
    pre_corpus.append(processed_text)

df_test_title = pd.DataFrame(pre_corpus, columns=["title"])
